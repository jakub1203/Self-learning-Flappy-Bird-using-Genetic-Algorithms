# %%
import pygame
import time
import random
import neat
import os
pygame.font.init()  # init font
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Initial inputs for our game 
X_screen = 500                                    # width of screen
Y_screen = 800                                    # length of screen
bird_image = pygame.image.load("bird.png")        # image of our object bird
super_image = pygame.image.load("super.png")        # image of our object bird
super_image = pygame.transform.scale(super_image, (bird_image.get_width()/2, bird_image.get_height()/2)) #chganging size of picture
STAT_FONT = pygame.font.SysFont("comicsans", 50)  # font of score drawn on screen

# %%
# Initial position of bird
bird_X = X_screen * 0.15   # initial x position of bird which is constant during game
bird_Y = Y_screen * 0.4    # initial y position of bird

# %%
# Assumptions for obstacles
rectangle_width = 70      # width of our obstacle
rectangle_gap = 150       # gap between top and bottom obstacle

# %%
class Bird:
    """
    Class Bird is representation of our bird in game. 
    It has functions up() which is used to move bird up. 
    Function change_position changing position of bird up or down, depends on player input. 
    Next function draw() draw bird on display and also maintain limitation of position of our bird.
    """
    
    def __init__(self, bird_X, bird_Y):
        self.x = bird_X          # x position of bird
        self.y = bird_Y          # y position of bird
        self.move = -7           # constant move of bird. It is negative because it is an upward move
        self.image = bird_image  # image of bird
        self.repeat = 0          # it shows how long program works without user action
        self.length = bird_image.get_height()
    
    def up(self):
        self.repeat = 0          # if user want to jump repeat is equal 0 
    
    
    def change_position(self):
        self.repeat += 1         # if the function is called 
        self.y = self.y + self.move*self.repeat + self.repeat**2  # this is line which is responsible for changing position of bird
                                                                  # if user don't call function up() the value becomes larger as the program runs
    
    def collision(self):                                        
        end = False
        if self.y < 0:          # checking if bird touch the top or bottom of screen, if so game ends
            end = True
        if self.y > (Y_screen - self.length):
            end = True
        return end
            
    
    def draw(self, screen):
        self.image = bird_image
        screen.blit(self.image, (self.x, self.y))                 # drawing bird based on new y position

# %%
class Obstacle:
    """
    Next class Obstacle generate obstacles in our game. There are four functions:
    First one set_high() generate random height of obstacle in range between 200 and 450. 
    The second function: change_position() is responsible for move of pipes. 
    it also checking if obstacle is out of window. If yes it creating new obstacle with new random height.
    Next function draw() creating a rectangles which are displayed on screen. 
    The last function collide() is checking is there a collision between bird and created obstacles. if yes it returns False. 
    """
    
    def __init__(self, x):
        self.x = x                       # x position of obstacle. By default size of screen (500)
        self.height = 0                  # height of top obstacle
        self.score = 0                   # how many obstacles player passed
        self.width = rectangle_width     # width of obstacle
        self.gap = rectangle_gap         # gap between top and bottom obstacle
        self.move = -3                   # speed of obstacle
        self.Y_screen = Y_screen         # size of screen 
        self.set_height()                # setting the initial value of height
        
    def set_height(self):
        self.height = random.randrange(200, 450)     # random value of height between 200 and 450 
    
    def change_position(self):                       
        self.x += self.move                          # changing position of obstacle based on initial value of speed
        if self.x <= -self.width:                    # if obstacle miss the screen creating new obstacle at the beggining
            self.x = 500
            self.set_height()
            self.score += 1
        return self.score
            
    def draw(self, screen):
        pygame.draw.rect(screen, (0, 0, 0), (self.x, 0, self.width, self.height))                        # drawing top obstacle
        height_second = self.Y_screen - self.height - self.gap       # height of the second obstacle based on length of screen, gap and height of first one
        pygame.draw.rect(screen, (0, 0, 0), (self.x, self.height + self.gap, self.width, height_second)) # drawing bottom obstacle
        
    def collide(self, bird):
        end = True
        if bird.x in range(self.x - self.width, self.x):
            if bird.y <= self.height or bird.y >= (self.height + self.gap - 50):   # checking if bird is on the same level as obstacles
                end = False
        return end

# %%
class SuperMario:
    """
    Class defines the behavior and characteristics of the Super Mario object, 
    including movement, position, and collision detection
    """
    
    def __init__(self):
        self.x = 500                             # initial x position for super mario 
        self.y = 200                             # initial y position for super mario
        self.speed = -3                          # initial speed 
        self.score = 0                           # how many marios we passed
        self.set_speed()                         # setting the initial
        self.image = super_image                 # image of super mario
        self.width = super_image.get_width()     # width of picture super mario
        self.height = super_image.get_height()   # length of picture super mario
        
    def set_height(self, obst):
        top_y = obst.height                      # length of top obstacle
        bottom_y = obst.height + obst.gap        # length of bottom obstacle
        if random.random()>= 0.5:                # we chose random if we want our super mario to "fly" above or under gap
            self.y = random.randrange(self.width, top_y)    # new y position of super mario
        else:
            self.y = random.randrange(bottom_y, Y_screen - self.width)    # new y position of super mario
    
    def set_speed(self):
        self.speed = random.randrange(-10, -5)   # random speed between -10 and -5 
    
    def change_position(self, obst):             
        self.x += self.speed                     # changing position based on new speed
        if self.x <= -self.width:                # if mario miis the screen, creating new one
            self.x = 500
            self.set_height(obst)
            self.set_speed()
            self.score += 1
        return self.score                        # return score which depends on obstacles we passed
            
    def draw(self, screen):
        screen.blit(self.image, (self.x, self.y))
        
    def collide(self, bird):                      
        bird_rect = bird.image.get_rect(topleft=(bird.x, bird.y))   # position of bird
        mario_rect = self.image.get_rect(topleft=(self.x, self.y))  # position of mario
        if bird_rect.colliderect(mario_rect):                       # checking if bird hits mario
            return True
        return False

# %%
def draw_screen(screen, birds, obst, score2, super_mario1, super_mario2):
    """
    Function used in the main fitness function. 
    It is used to draw all the necessary elements and refresh the screen.
    """
    
    screen.fill((255, 255, 255))      # filling background with white colour
    obst.draw(screen)                 # drawing obstacles
    super_mario1.draw(screen)         # drawing first super mario
    super_mario2.draw(screen)         # drawing second super mario
    
    for bird in birds:                # drawing all birds
        bird.draw(screen)
    
    score_label = STAT_FONT.render("Score: " + str(score2),1,(0,255,0))      # defining text of score
    screen.blit(score_label, (X_screen - score_label.get_width() - 15, 10))  # drawing score on board
    pygame.display.update()           # displaying screen

# %%
def end_game(birds):
    if len(birds) == 0:  # if all birds death, the loop is over
            return True

# %%
def fitness(genomes, config):
    """
    The fitness function updates the position of birds in the game based on their neural network output. 
    If a bird successfully passes through an obstacle, its genome's fitness is increased, 
    while a collision results in a decrease in fitness. 
    The function removes birds with low fitness scores and their corresponding neural networks and genomes. 
    This process is repeated until the game is over.
    """
    
    nets = []         # list for neural network nets for each birds
    ge = []           # list of genomes (birds)
    birds = []        # list of objects birds
    
    for x, g in genomes:
        net = neat.nn.FeedForwardNetwork.create(g, config)  # creating neural network net bassed on particular genom and config that are fixed
        nets.append(net)                                    # append neural network net to list
        birds.append(Bird(bird_X, bird_Y))                  # append object of bird to list
        g.fitness = 0                                       # fix fitness value of every genom as 0 
        ge.append(g)                                        # append genom to ge list
    
    screen = pygame.display.set_mode((X_screen, Y_screen))  # initial pygame display 

    
    obst = Obstacle(X_screen)                               # creating obstacle object
    
    
    super_mario1 = SuperMario()                             # creating two super mario obstacles
    super_mario2 = SuperMario()
    
    clock = pygame.time.Clock()                             # creating object time.clock() which helps with game speed management
    
    score1 = 0                                              # variables needed during calculations
    score3 = 0
    score5 = 0

    start = True
    while start:
        
        clock.tick(50)                       # setting tick for 50 in order to slow down the game
        for event in pygame.event.get():     #checking if user click the quit button 
            if event.type == pygame.QUIT:
                start = False
                pygame.quit()
        
        for x, bird in enumerate(birds):
            ge[x].fitness += 0.01           # if one loop pass we add 0.01 to every bird that survived
            bird.change_position()          # changing position of all birds
            
            # using inputs such to calculate if jump or not
            # first input: distance between y position of bird and position of top obstacle
            # second input: distance between y position of bird and position of bottom obstacle
            # third and fourth: Euclidean distance between the position of the "bird" and "super_mario1/2" 
            output = nets[x].activate((abs(bird.y - obst.height), abs(bird.y - obst.height - obst.gap+50), 
                                      ((bird.x - super_mario1.x)**2 + (bird.y - super_mario1.y)**2)**(1/2),
                                      ((bird.x - super_mario2.x)**2 + (bird.y - super_mario2.y)**2)**(1/2),
                                      abs(bird.y - super_mario1.y), abs(bird.y - super_mario2.y)))
            
            # if output of calculation is higher than 0.5 bird should jump 
            if output[0] > 0.5:
                bird.up()
        
        
        
        
        
        
        # this part of score is responsible for moving obstacles and also for countin score
        # it also check if our bird passed the obstacle, if so the bird get 5 points
        score2 = obst.change_position()
        if score2 > score1:
            for x, bird in enumerate(birds):
                ge[x].fitness += 5
        score1 = score2
        
        
        # this part of score is responsible for moving super_mario1 and also for countin score
        # it also check if our bird passed the super_mario1, if so the bird get 0.3 points
        score4 = super_mario1.change_position(obst)
        if score4 > score3:
            for x, bird in enumerate(birds):
                ge[x].fitness += 0.3
        score3 = score4
        
        
        # this part of score is responsible for moving super_mario2 and also for countin score
        # it also check if our bird passed the super_mario2, if so the bird get 0.3 points
        score6 = super_mario2.change_position(obst)
        if score4 > score3:
            for x, bird in enumerate(birds):
                ge[x].fitness += 0.3
        score5 = score6
        
        
        # Checking if bird hit the top or bottom part of screen
        for x, bird in enumerate(birds):
            if bird.collision() == True:
                ge[x].fitness -= 2
                birds.pop(x)
                nets.pop(x)
                ge.pop(x)
                
        if end_game(birds): break                           # checking if all bird are death
        
                
        # check if bird hit obstacle
        for x, bird in enumerate(birds):
            if obst.collide(bird) == False:
                ge[x].fitness -= 1
                birds.pop(x)
                nets.pop(x)
                ge.pop(x)
        if end_game(birds): break                           # checking if all bird are death
        
        
        #check if bird hits super_mario1/2
        for x, bird in enumerate(birds):
            if super_mario1.collide(bird) == True or super_mario2.collide(bird) == True:
                ge[x].fitness -= 5
                birds.pop(x)
                nets.pop(x)
                ge.pop(x)
                
        if end_game(birds): break                           # checking if all bird are death
            
        
        draw_screen(screen, birds, obst, score2, super_mario1, super_mario2)  #drawing all neccesary elements

# %%
def run(config_file):
    """
    This function contains all the assumptions for our algorithm based on config_file 
    which is file that represents all inputs that are needed to run the algorithm. 
    """
    
    #Arguments in function providethe default settings for the genomes, 
    #reproduction, species, and stagnation of the NEAT algorithm.
    config = neat.config.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)
    
    
    #based on config we create our population (50 chromosoms)
    population = neat.Population(config)
    
    # add statistic 
    population.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    population.add_reporter(stats)
    
    #our winner after 50 iterations
    winner = population.run(fitness, 50)
    print(winner)

# %%
if __name__ == "__main__":
    
    # upload file with assesments to model
    __file__ = os.path.abspath("Untitled.py")
    local_dir = os.path.dirname(__file__)
    config_path = os.path.join(local_dir, 'Config_file.txt')
    run(config_path)  # running algorithm
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -2.00680 stdev: 1.13363
# Best fitness: 0.50000 - size: (1, 6) - species 1 - id 29
# Average adjusted fitness: 0.510
# Mean genetic distance 0.985, standard deviation 0.394
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    50      0.5    0.510     0
# Total extinctions: 0
# Generation time: 2.582 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -1.92660 stdev: 1.45012
# Best fitness: 0.53000 - size: (1, 6) - species 1 - id 10
# Average adjusted fitness: 0.523
# Mean genetic distance 1.207, standard deviation 0.404
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    50      0.5    0.523     0
# Total extinctions: 0
# Generation time: 2.508 sec (2.545 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -1.74980 stdev: 1.05229
# Best fitness: 0.96000 - size: (1, 5) - species 1 - id 66
# Average adjusted fitness: 0.514
# Mean genetic distance 1.078, standard deviation 0.387
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    50      1.0    0.514     0
# Total extinctions: 0
# Generation time: 2.803 sec (2.631 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -2.12620 stdev: 1.57571
# Best fitness: 1.01000 - size: (1, 3) - species 1 - id 192
# Average adjusted fitness: 0.439
# Mean genetic distance 1.167, standard deviation 0.383
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3    50      1.0    0.439     0
# Total extinctions: 0
# Generation time: 2.887 sec (2.695 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -1.54020 stdev: 0.97977
# Best fitness: 0.55000 - size: (1, 3) - species 1 - id 192
# Average adjusted fitness: 0.593
# Mean genetic distance 1.256, standard deviation 0.481
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    50      0.6    0.593     1
# Total extinctions: 0
# Generation time: 2.567 sec (2.669 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -1.83740 stdev: 1.80460
# Best fitness: 2.63000 - size: (2, 5) - species 1 - id 280
# Average adjusted fitness: 0.387
# Mean genetic distance 1.712, standard deviation 0.381
# Population of 50 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    50      2.6    0.387     0
# Total extinctions: 0
# Generation time: 4.127 sec (2.912 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -0.85940 stdev: 2.61877
# Best fitness: 10.65000 - size: (1, 2) - species 1 - id 297
# Average adjusted fitness: 0.241
# Mean genetic distance 1.792, standard deviation 0.519
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    45     10.6    0.241     0
#      2    0     5       --       --     0
# Total extinctions: 0
# Generation time: 8.510 sec (3.712 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 0.21560 stdev: 3.97255
# Best fitness: 12.26000 - size: (2, 4) - species 1 - id 364
# Average adjusted fitness: 0.237
# Mean genetic distance 1.993, standard deviation 0.721
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    38     12.3    0.297     0
#      2    1    12     -1.4    0.176     0
# Total extinctions: 0
# Generation time: 10.485 sec (4.559 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -0.03380 stdev: 8.21220
# Best fitness: 48.81000 - size: (1, 2) - species 1 - id 399
# Average adjusted fitness: 0.076
# Mean genetic distance 2.039, standard deviation 0.817
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    32     48.8    0.095     0
#      2    2    18     -1.4    0.057     0
# Total extinctions: 0
# Generation time: 27.594 sec (7.118 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -0.04420 stdev: 4.95322
# Best fitness: 18.48000 - size: (1, 2) - species 1 - id 454
# Average adjusted fitness: 0.188
# Mean genetic distance 2.059, standard deviation 0.829
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    32     18.5    0.230     1
#      2    3    18      0.9    0.145     0
# Total extinctions: 0
# Generation time: 12.352 sec (7.642 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: 0.75300 stdev: 6.21337
# Best fitness: 20.09000 - size: (1, 2) - species 1 - id 454
# Average adjusted fitness: 0.206
# Mean genetic distance 1.873, standard deviation 0.772
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10    31     20.1    0.243     2
#      2    4    19     20.1    0.169     0
# Total extinctions: 0
# Generation time: 14.664 sec (8.850 average)
#
#  ****** Running generation 11 ******
#
# Population's average fitness: 2.23940 stdev: 6.83247
# Best fitness: 17.95000 - size: (1, 2) - species 1 - id 558
# Average adjusted fitness: 0.272
# Mean genetic distance 1.885, standard deviation 0.695
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11    33     18.0    0.383     3
#      2    5    17      2.9    0.162     1
# Total extinctions: 0
# Generation time: 12.030 sec (9.802 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: 5.70260 stdev: 14.49704
# Best fitness: 56.44000 - size: (1, 2) - species 1 - id 599
# Average adjusted fitness: 0.122
# Mean genetic distance 1.929, standard deviation 0.864
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12    37     56.4    0.177     0
#      2    6    13     28.4    0.066     0
# Total extinctions: 0
# Generation time: 31.317 sec (12.653 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: 0.58200 stdev: 3.35867
# Best fitness: 5.95000 - size: (1, 2) - species 1 - id 636
# Average adjusted fitness: 0.316
# Mean genetic distance 2.022, standard deviation 1.000
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13    34      5.9    0.306     1
#      2    7    16      5.9    0.325     1
# Total extinctions: 0
# Generation time: 7.723 sec (13.137 average)
#
#  ****** Running generation 14 ******
#
# Population's average fitness: 1.78440 stdev: 4.98991
# Best fitness: 21.18000 - size: (1, 2) - species 1 - id 691
# Average adjusted fitness: 0.238
# Mean genetic distance 2.080, standard deviation 1.073
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14    32     21.2    0.252     2
#      2    8    18      4.5    0.223     2
# Total extinctions: 0
# Generation time: 11.777 sec (14.058 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -0.60040 stdev: 3.70405
# Best fitness: 13.35000 - size: (1, 2) - species 1 - id 685
# Average adjusted fitness: 0.112
# Mean genetic distance 2.258, standard deviation 1.200
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15    38     13.3    0.175     3
#      2    9    12      0.5    0.049     3
# Total extinctions: 0
# Generation time: 7.806 sec (14.426 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: 0.18040 stdev: 4.55238
# Best fitness: 11.23000 - size: (1, 2) - species 1 - id 774
# Average adjusted fitness: 0.261
# Mean genetic distance 2.527, standard deviation 1.403
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16    35     11.2    0.341     4
#      2   10    15      0.5    0.181     4
# Total extinctions: 0
# Generation time: 9.005 sec (14.475 average)
#
#  ****** Running generation 17 ******
#
# Population's average fitness: 8.47900 stdev: 22.52308
# Best fitness: 74.64000 - size: (1, 2) - species 1 - id 814
# Average adjusted fitness: 0.130
# Mean genetic distance 2.644, standard deviation 1.284
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17    40     74.6    0.217     0
#      2   11    10      0.6    0.043     5
# Total extinctions: 0
# Generation time: 39.034 sec (17.330 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: 6.96080 stdev: 19.38498
# Best fitness: 59.60000 - size: (1, 2) - species 1 - id 889
# Average adjusted fitness: 0.135
# Mean genetic distance 2.919, standard deviation 1.476
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18    44     59.6    0.211     1
#      2   12     6     15.8    0.059     6
# Total extinctions: 0
# Generation time: 33.399 sec (17.911 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: 0.45160 stdev: 3.07032
# Best fitness: 5.95000 - size: (2, 5) - species 1 - id 910
# Average adjusted fitness: 0.527
# Mean genetic distance 2.732, standard deviation 1.493
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19    33      5.9    0.467     2
#      2   13    17      5.9    0.586     7
# Total extinctions: 0
# Generation time: 4.842 sec (17.160 average)
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -1.55840 stdev: 2.30112
# Best fitness: 6.23000 - size: (1, 3) - species 2 - id 942
# Average adjusted fitness: 0.289
# Mean genetic distance 2.848, standard deviation 1.650
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20    29      2.6    0.246     3
#      2   14    21      6.2    0.333     8
# Total extinctions: 0
# Generation time: 4.770 sec (16.170 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -2.01660 stdev: 1.76953
# Best fitness: 2.59000 - size: (2, 4) - species 1 - id 1007
# Average adjusted fitness: 0.246
# Mean genetic distance 2.969, standard deviation 1.747
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21    35      2.6    0.298     4
#      2   15    15      0.5    0.194     9
# Total extinctions: 0
# Generation time: 4.064 sec (15.374 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -1.29960 stdev: 3.00828
# Best fitness: 16.10000 - size: (2, 4) - species 2 - id 1046
# Average adjusted fitness: 0.164
# Mean genetic distance 2.923, standard deviation 1.596
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22    31      5.6    0.150     5
#      2   16    19     16.1    0.178    10
# Total extinctions: 0
# Generation time: 10.175 sec (13.260 average)
#
#  ****** Running generation 23 ******
#
# Population's average fitness: 2.27640 stdev: 5.48581
# Best fitness: 19.68000 - size: (1, 2) - species 1 - id 1103
# Average adjusted fitness: 0.287
# Mean genetic distance 3.113, standard deviation 1.804
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23    30     19.7    0.268     6
#      2   17    20     13.4    0.307    11
# Total extinctions: 0
# Generation time: 14.260 sec (13.913 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: 5.73660 stdev: 17.48387
# Best fitness: 81.45000 - size: (1, 2) - species 1 - id 1103
# Average adjusted fitness: 0.111
# Mean genetic distance 3.312, standard deviation 1.877
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24    29     81.5    0.157     0
#      2   18    17     23.8    0.064    12
#      3    0     4       --       --     0
# Total extinctions: 0
# Generation time: 45.149 sec (17.250 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: 0.94580 stdev: 4.06659
# Best fitness: 10.11000 - size: (1, 2) - species 1 - id 1193
# Average adjusted fitness: 0.348
# Mean genetic distance 3.088, standard deviation 1.511
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   25    16     10.1    0.419     1
#      2   19    15      8.4    0.332    13
#      3    1    19      3.8    0.293     0
# Total extinctions: 0
# Generation time: 7.956 sec (17.265 average)
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -0.89900 stdev: 1.95863
# Best fitness: 2.60000 - size: (1, 2) - species 1 - id 1244
# Average adjusted fitness: 0.487
# Mean genetic distance 3.405, standard deviation 1.791
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   26    20      2.6    0.552     2
#      2   20    12      2.6    0.395    14
#      3    2    17      2.6    0.513     1
# Total extinctions: 0
# Generation time: 4.097 sec (16.775 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: 1.86735 stdev: 6.22938
# Best fitness: 20.01000 - size: (1, 2) - species 1 - id 1296
# Average adjusted fitness: 0.258
# Mean genetic distance 3.585, standard deviation 1.975
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   27    21     20.0    0.296     3
#      2   21    11     13.1    0.217    15
#      3    3    19     10.2    0.261     0
# Total extinctions: 0
# Generation time: 14.951 sec (14.366 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: 20.23216 stdev: 38.61517
# Best fitness: 95.07000 - size: (1, 2) - species 1 - id 1335
# Average adjusted fitness: 0.208
# Mean genetic distance 3.211, standard deviation 1.795
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   28    24     95.1    0.320     0
#      2   22     5      6.8    0.024    16
#      3    4    22     95.1    0.280     0
# Total extinctions: 0
# Generation time: 51.281 sec (16.155 average)
#
#  ****** Running generation 29 ******
#
# Population's average fitness: 3.88275 stdev: 8.92193
# Best fitness: 34.85000 - size: (1, 2) - species 1 - id 1371
# Average adjusted fitness: 0.125
# Mean genetic distance 3.394, standard deviation 1.970
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   29    23     34.9    0.192     1
#      2   23     5      0.5    0.038    17
#      3    5    22     11.2    0.143     1
# Total extinctions: 0
# Generation time: 21.062 sec (17.777 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -0.30120 stdev: 2.67234
# Best fitness: 13.45000 - size: (1, 2) - species 1 - id 1421
# Average adjusted fitness: 0.131
# Mean genetic distance 3.147, standard deviation 1.900
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   30    19     13.4    0.137     2
#      2   24    10      2.9    0.157    18
#      3    6    20      2.9    0.099     2
# Total extinctions: 0
# Generation time: 8.100 sec (18.110 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: 1.20184 stdev: 6.43214
# Best fitness: 17.89000 - size: (1, 2) - species 1 - id 1475
# Average adjusted fitness: 0.237
# Mean genetic distance 3.178, standard deviation 1.848
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   31    15     17.9    0.245     3
#      2   25     8      0.5    0.128    19
#      3    7    26     17.9    0.337     3
# Total extinctions: 0
# Generation time: 11.806 sec (18.884 average)
#
#  ****** Running generation 32 ******
#
# Population's average fitness: 6.41000 stdev: 14.10351
# Best fitness: 36.17000 - size: (1, 2) - species 3 - id 1496
#
# Species 2 with 8 members is stagnated: removing it
# Average adjusted fitness: 0.281
# Mean genetic distance 2.002, standard deviation 0.902
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   32    25     36.2    0.385     4
#      3    8    25     36.2    0.177     4
# Total extinctions: 0
# Generation time: 19.604 sec (19.827 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: 2.19220 stdev: 7.13418
# Best fitness: 34.11000 - size: (1, 2) - species 3 - id 1533
# Average adjusted fitness: 0.176
# Mean genetic distance 2.072, standard deviation 0.880
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   33    27     12.4    0.151     5
#      3    9    23     34.1    0.201     5
# Total extinctions: 0
# Generation time: 20.231 sec (20.424 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -0.38440 stdev: 1.91219
# Best fitness: 2.75000 - size: (1, 2) - species 1 - id 1577
# Average adjusted fitness: 0.514
# Mean genetic distance 1.942, standard deviation 0.819
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   34    22      2.7    0.573     6
#      3   10    28      2.7    0.455     6
# Total extinctions: 0
# Generation time: 4.364 sec (16.345 average)
#
#  ****** Running generation 35 ******
#
# Population's average fitness: 3.00900 stdev: 7.59359
# Best fitness: 17.91000 - size: (1, 2) - species 1 - id 1655
# Average adjusted fitness: 0.240
# Mean genetic distance 1.732, standard deviation 0.859
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   35    18     17.9    0.192     7
#      3   11    32     17.9    0.288     7
# Total extinctions: 0
# Generation time: 11.845 sec (16.734 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: 2.86560 stdev: 5.80670
# Best fitness: 10.66000 - size: (1, 2) - species 1 - id 1702
# Average adjusted fitness: 0.491
# Mean genetic distance 1.854, standard deviation 0.815
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   36    19     10.7    0.489     8
#      3   12    31     10.6    0.493     8
# Total extinctions: 0
# Generation time: 8.476 sec (17.172 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: 6.40920 stdev: 12.15933
# Best fitness: 36.82000 - size: (1, 2) - species 3 - id 1748
# Average adjusted fitness: 0.270
# Mean genetic distance 1.747, standard deviation 0.795
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   37    23     36.8    0.296     9
#      3   13    27     36.8    0.245     9
# Total extinctions: 0
# Generation time: 19.645 sec (17.641 average)
#
#  ****** Running generation 38 ******
#
# Population's average fitness: 8.19040 stdev: 13.19213
# Best fitness: 28.75000 - size: (1, 2) - species 1 - id 1771
# Average adjusted fitness: 0.356
# Mean genetic distance 1.857, standard deviation 0.774
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   38    20     28.8    0.251    10
#      3   14    30     28.7    0.460    10
# Total extinctions: 0
# Generation time: 15.811 sec (14.094 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: 1.80440 stdev: 13.19239
# Best fitness: 64.10000 - size: (1, 2) - species 3 - id 1841
# Average adjusted fitness: 0.079
# Mean genetic distance 2.125, standard deviation 1.050
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   39    19     64.1    0.092    11
#      3   15    31     64.1    0.067    11
# Total extinctions: 0
# Generation time: 34.915 sec (15.480 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -0.59560 stdev: 1.66579
# Best fitness: 2.63000 - size: (1, 2) - species 3 - id 1861
# Average adjusted fitness: 0.288
# Mean genetic distance 1.946, standard deviation 0.999
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   40    19      2.6    0.329    12
#      3   16    31      2.6    0.248    12
# Total extinctions: 0
# Generation time: 4.122 sec (15.082 average)
#
#  ****** Running generation 41 ******
#
# Population's average fitness: -0.75640 stdev: 3.28121
# Best fitness: 13.37000 - size: (1, 2) - species 3 - id 1861
# Average adjusted fitness: 0.178
# Mean genetic distance 1.941, standard deviation 1.022
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   41    23     13.4    0.200    13
#      3   17    24     13.4    0.156    13
#      4    0     3       --       --     0
# Total extinctions: 0
# Generation time: 7.829 sec (14.684 average)
#
#  ****** Running generation 42 ******
#
# Population's average fitness: 3.48300 stdev: 16.26994
# Best fitness: 110.31000 - size: (1, 2) - species 1 - id 1956
#
# Best individual in generation 42 meets fitness threshold - complexity: (1, 2)
# Key: 1956
# Fitness: 110.31000000000488
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=2.657293230589534, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-2, 0), weight=-3.9189117448825055, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=1.3541039112574031, enabled=True)
